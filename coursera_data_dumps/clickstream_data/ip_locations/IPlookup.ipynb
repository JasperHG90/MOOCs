# %%
'''
This script looks up the IP address information for MOOC users
Written by : Jasper Ginn
Date : 23-03-2015
Last modified : 24-03-2015
Please send suggestions/comments to : Jasperginn@cdh.leidenuniv.nl
'''

# --------------------------------------------------------------------------------

'''
Import modules
'''

# Import IPwhois
from ipwhois import IPWhois
# Import SQLite
import sqlite3 as lite

# %%
'''
+++ MAIN FUNCTION +++
'''

def mainFunction(dbname, dbpath, tablename_o, tablename_n, override = "TRUE"):
    # Setup database
    dbSetup(dbname, tablename_n, path = dbpath, override = override)
    # Get IP addresses
    q = getIPs(dbname, dbpath, tablename_o)
    # For each IP, get country code
    for IP in q:
        # Check if there is more than 1 IP address
        iplen = len(IP.split(','))
        # If longer than 1, then we have more IP addresses
        if iplen > 1:
            # For every IP, do . . .
            for ipobs in IP.split(','):
                # Replace whitespace
                ipobs = ipobs.replace(" ", "")
                # Check if already in db
                res = dbCheck(ipobs, dbname, tablename_n, dbpath)
                if res != None and override == "FALSE":
                    continue
                else:
                    try:
                        # Look up
                        vals = [ ( ipobs, IPtoCC(ipobs) ) ]
                        # Insert into database
                        dbInsert(vals, dbname, tablename_n , path = dbpath)
                    except: # IPdefinedError
                        print('There was an error . . . moving on')
        else:
            # Check if already in db
            res = dbCheck(IP, dbname, tablename_n, dbpath)
            if res != None and override == "FALSE":
                continue
            else:
                try:
                    # Look up
                    vals = [ ( IP, IPtoCC(IP) ) ]
                    # Insert into database
                    dbInsert(vals, dbname, tablename_n , path = dbpath)
                except: # IPdefinedError
                    print('There was an error . . . moving on')

# %%
'''
+++ HELPER FUNCTIONS +++
'''

'''
FUNCTION 1 : Helper function that creates the path for the database. It evaluates whether the path specified by the user ends with
'/'. If yes, then paste. If no, then add the '/' to avoid problems.
    parameters :
        dbname : string
            name of the database
        path : string
            system path where the database is stored. Defaults to '~/desktop'
'''

def pathMaker(dbname, path):
    if path.endswith('/'):
        return(path + dbname + '.db')
    else:
        return(path + '/' + dbname + '.db')
    
'''
FUNCTION 2 : Helper function that retrieves all the IP addresses from the database, stores them in a list. 
    parameters :
        db_name : string
            name of database
        db_path : string
            path to the database
        table_name : string
            table in which IP addresses are stored
'''

def getIPs(db_name, db_path, table_name):
    # Create path to db
    dbpath = pathMaker(db_name, db_path)
    # Connect
    conn = lite.connect(dbpath)
    # With connection, do . . .
    with conn:    
        # Cursor
        cur = conn.cursor()
        # Select all observations in the db
        cur.execute("SELECT * FROM {}".format(table_name))
        # Fetch the rows
        rows = cur.fetchall()
        # Store tuples in list
        IPs = [ row[0] 
                for row in rows ]
    # Close connection
    conn.close()
    # Return
    return(IPs)

'''
FUNCTION 3 : Convert IP address to country code (two-letter cc)
    parameters :
        IP_address : string
            IPv4 or IPv6 address to convert 
'''

def IPtoCC(IP_address):
    # Look up the address
    obj = IPWhois(IP_address)
    results = obj.lookup()
    # return cc
    return(results['asn_country_code'])

'''
FUNCTION 4 : create the SQLite database and commit headers
    Parameters :
        dbname    : string
            name of the database
        tablename : string
            name of the table in which to store results
        path  : string
            path to store database. Defaults to '/home/vagrant/Documents/'
'''

def dbSetup(dbname, tablename, path = '~/desktop', override = "TRUE"):
    # Want to replace the database?
    if override == 'TRUE':
        pathfile = pathMaker(dbname, path)
        con = lite.connect(pathfile)
        cur = con.cursor()
        # send headers and create table
        cur.execute("DROP TABLE IF EXISTS {};".format(tablename))
        cur.execute("CREATE TABLE {}(IP TEXT, CC TEXT);".format(tablename))
        # Commit
        con.commit()
    else:
        print "A table with the name {} already exists for path {}. You specified the override option to be {}. The database will be left alone . . . yay!".format(dbname, path, str(override))

'''
FUNCTION 5 : Insert results form each page to the database
    Parameters :
        values_list : list 
            list of values to send to the database
        dbname      : string
            name of the database
        tablename   : string
            name of the table in which to store results
        path        : string
            path to the database. Defaults to '/home/vagrant/Documents/'
'''

def dbInsert(values_list, dbname, tablename , path = '~/desktop/'):
    # Path to db
    pathfile = pathMaker(dbname, path)
    # Try connecting and inserting
    try:
        con = lite.connect(pathfile) 
        with con:  
            # Cursor file
            cur = con.cursor()
            # Write values to db
            cur.executemany("INSERT INTO {} (IP, CC) VALUES(?, ?);".format(tablename), values_list)
            # Commit (i.e. save) changes
            con.commit()
        # Close connection
        con.close()           
    except:
        print 'Error while setting up the database. Quitting the script now . . . '
        
'''
FUNCTION 9 : Helper function to check whether an IP already exists in the database. Here, we are checking the specific IP
(which is basically a unique ID) against all IPs that already exist in the db.
    parameters : 
        url : string
            url of the specific report at reclaimnaija
        dbname : string
            name of the database
        dbtable : string
            table in which reclaimnaija results are stored
        path : string
            system path where the database is stored. Defaults to '~/desktop'
'''

def dbCheck(IP_add, dbname, dbtable, path = '~/desktop/'):
    pathsal = pathMaker(dbname, path)
    con = lite.connect(pathsal)
    # Cursor file
    with con:
        cur = con.cursor()
        cur.execute("SELECT IP FROM {} WHERE IP = ?".format(dbtable), (IP_add,))
        data=cur.fetchone()
        if data is None:
            return(None)
        else:
            print('Report for IP {} already in database . . . moving on'.format(IP_add))
            return(data[0])
    # Close db connection
    con.close()

# %%
'''
+++ RUN +++
'''

# Details
dbname = "IP_clickstream_metals-001"
dbpath = "/users/jasper/documents/github.projects/C4I/projects/clickstream_data/data"
tablename_o = "IPadresses"
tablename_n = "IPandCC"

# Run
mainFunction(dbname, dbpath, tablename_o, tablename_n, override = "FALSE")
# Out:
# A table with the name IP_clickstream_metals-001 already exists for path /users/jasper/documents/github.projects/C4I/projects/clickstream_data/data. You specified the override option to be FALSE. The database will be left alone . . . yay!
# Report for IP 123.239.50.208 already in database . . . moving on
# Report for IP 196.46.246.176 already in database . . . moving on
# Report for IP 50.67.80.97 already in database . . . moving on
# Report for IP 96.48.19.231 already in database . . . moving on
# Report for IP 41.190.2.195 already in database . . . moving on
# Report for IP 58.106.61.93 already in database . . . moving on
# Report for IP 195.67.21.7 already in database . . . moving on
# Report for IP 42.60.171.245 already in database . . . moving on
# Report for IP 177.242.171.210 already in database . . . moving on
# Report for IP 186.31.127.117 already in database . . . moving on
# Report for IP 68.151.48.167 already in database . . . moving on
# Report for IP 124.13.6.255 already in database . . . moving on
# Report for IP 174.77.220.178 already in database . . . moving on
# Report for IP 183.48.37.9 already in database . . . moving on
# Report for IP 24.193.147.48 already in database . . . moving on
# Report for IP 196.46.245.153 already in database . . . moving on
# Report for IP 196.46.245.148 already in database . . . moving on
# Report for IP 196.46.245.155 already in database . . . moving on
# Report for IP 196.46.246.182 already in database . . . moving on
# Report for IP 173.61.13.100 already in database . . . moving on
# Report for IP 196.46.246.183 already in database . . . moving on
# Report for IP 196.46.246.181 already in database . . . moving on
# Report for IP 82.227.5.79 already in database . . . moving on
# Report for IP 196.46.246.178 already in database . . . moving on
# Report for IP 196.46.246.179 already in database . . . moving on
# Report for IP 196.46.246.180 already in database . . . moving on
# Report for IP 76.175.3.150 already in database . . . moving on
# Report for IP 196.46.245.154 already in database . . . moving on
# Report for IP 93.139.150.151 already in database . . . moving on
# Report for IP 196.46.245.152 already in database . . . moving on
# Report for IP 192.252.136.131 already in database . . . moving on
# Report for IP 123.236.58.118 already in database . . . moving on
# Report for IP 196.46.245.150 already in database . . . moving on
# Report for IP 105.229.79.252 already in database . . . moving on
# Report for IP 207.67.7.250 already in database . . . moving on
# Report for IP 86.33.48.115 already in database . . . moving on
# Report for IP 86.3.68.211 already in database . . . moving on
# Report for IP 70.72.175.212 already in database . . . moving on
# Report for IP 46.59.18.188 already in database . . . moving on
# Report for IP 5.160.95.130 already in database . . . moving on
# Report for IP 194.15.138.11 already in database . . . moving on
# Report for IP 200.179.25.178 already in database . . . moving on
# Report for IP 123.138.215.26 already in database . . . moving on
# Report for IP 210.22.62.186 already in database . . . moving on
# Report for IP 113.57.187.53 already in database . . . moving on
# Report for IP 92.254.17.226 already in database . . . moving on
# Report for IP 124.166.242.170 already in database . . . moving on
# Report for IP 41.190.3.103 already in database . . . moving on
# Report for IP 41.190.95.48 already in database . . . moving on
# Report for IP 210.212.252.74 already in database . . . moving on
# Report for IP 210.245.52.189 already in database . . . moving on
# Report for IP 142.136.178.21 already in database . . . moving on
# Report for IP 187.191.7.134 already in database . . . moving on
# Report for IP 162.210.167.14 already in database . . . moving on
# Report for IP 181.28.134.119 already in database . . . moving on
# Report for IP 81.158.173.33 already in database . . . moving on
# Report for IP 74.101.63.154 already in database . . . moving on
# Report for IP 99.118.4.229 already in database . . . moving on
# Report for IP 83.84.183.132 already in database . . . moving on
# Report for IP 197.237.104.90 already in database . . . moving on
# Report for IP 202.45.187.107 already in database . . . moving on
# Report for IP 75.69.182.68 already in database . . . moving on
# Report for IP 151.47.94.173 already in database . . . moving on
# Report for IP 94.219.126.72 already in database . . . moving on
# Report for IP 189.121.87.138 already in database . . . moving on
# Report for IP 67.170.202.251 already in database . . . moving on
# Report for IP 190.119.60.158 already in database . . . moving on
# Report for IP 74.61.103.39 already in database . . . moving on
# Report for IP 83.160.49.25 already in database . . . moving on
# Report for IP 79.177.19.78 already in database . . . moving on
# Report for IP 80.218.98.192 already in database . . . moving on
# Report for IP 85.115.52.180 already in database . . . moving on
# Report for IP 173.61.49.205 already in database . . . moving on
# Report for IP 210.22.163.186 already in database . . . moving on
# Report for IP 187.135.34.244 already in database . . . moving on
# Report for IP 91.158.246.229 already in database . . . moving on
# Report for IP 93.50.208.138 already in database . . . moving on
# Report for IP 67.49.81.214 already in database . . . moving on
# Report for IP 221.239.122.208 already in database . . . moving on
# Report for IP 195.182.194.159 already in database . . . moving on
# Report for IP 93.39.6.235 already in database . . . moving on
# Report for IP 46.176.94.207 already in database . . . moving on
# Report for IP 124.180.199.195 already in database . . . moving on
# Report for IP 86.163.52.109 already in database . . . moving on
# Report for IP 41.37.206.22 already in database . . . moving on
# Report for IP 60.30.120.61 already in database . . . moving on
# Report for IP 78.139.4.90 already in database . . . moving on
# Report for IP 89.143.130.217 already in database . . . moving on
# Report for IP 193.191.216.77 already in database . . . moving on
# Report for IP 201.191.255.115 already in database . . . moving on
# Report for IP 86.136.178.188 already in database . . . moving on
# Report for IP 14.139.180.102 already in database . . . moving on
# Report for IP 212.175.177.123 already in database . . . moving on
# Report for IP 180.251.234.83 already in database . . . moving on
# Report for IP 178.157.49.237 already in database . . . moving on
# Report for IP 37.57.176.208 already in database . . . moving on
# Report for IP 103.229.120.201 already in database . . . moving on
# Report for IP 222.164.155.146 already in database . . . moving on
# Report for IP 202.161.103.139 already in database . . . moving on
# Report for IP 118.93.249.214 already in database . . . moving on
# Report for IP 60.246.146.131 already in database . . . moving on
# Report for IP 159.149.118.41 already in database . . . moving on
# Report for IP 87.212.48.128 already in database . . . moving on
# Report for IP 213.154.2.159 already in database . . . moving on
# Report for IP 109.72.34.117 already in database . . . moving on
# Report for IP 181.141.149.10 already in database . . . moving on
# Report for IP 202.36.137.5 already in database . . . moving on
# Report for IP 125.238.150.214 already in database . . . moving on
# Report for IP 201.160.157.128 already in database . . . moving on
# Report for IP 186.15.204.139 already in database . . . moving on
# Report for IP 76.169.84.64 already in database . . . moving on
# Report for IP 101.167.49.67 already in database . . . moving on
# Report for IP 189.137.158.82 already in database . . . moving on
# Report for IP 118.69.76.207 already in database . . . moving on
# Report for IP 72.252.153.21 already in database . . . moving on
# Report for IP 82.169.224.112 already in database . . . moving on
# Report for IP 93.144.127.128 already in database . . . moving on
# Report for IP 101.170.42.161 already in database . . . moving on
# Report for IP 158.182.114.147 already in database . . . moving on
# Report for IP 174.89.6.225 already in database . . . moving on
# Report for IP 87.167.51.24 already in database . . . moving on
# Report for IP 14.141.49.238 already in database . . . moving on
# Report for IP 58.178.78.224 already in database . . . moving on
# Report for IP 2.84.177.178 already in database . . . moving on
# Report for IP 175.136.204.142 already in database . . . moving on
# Report for IP 68.226.179.220 already in database . . . moving on
# Report for IP 115.127.12.247 already in database . . . moving on
# Report for IP 197.134.127.239 already in database . . . moving on
# Report for IP 122.175.17.151 already in database . . . moving on
# Report for IP 194.127.209.156 already in database . . . moving on
# Report for IP 50.187.42.137 already in database . . . moving on
# Report for IP 50.136.183.19 already in database . . . moving on
# Report for IP 186.117.128.6 already in database . . . moving on
# Report for IP 93.232.221.26 already in database . . . moving on
# Report for IP 72.168.162.159 already in database . . . moving on
# Report for IP 115.163.185.254 already in database . . . moving on
# Report for IP 98.239.128.212 already in database . . . moving on
# Report for IP 154.5.28.67 already in database . . . moving on
# Report for IP 72.168.167.112 already in database . . . moving on
# Report for IP 36.82.47.6 already in database . . . moving on
# Report for IP 121.222.197.143 already in database . . . moving on
# Report for IP 72.168.169.212 already in database . . . moving on
# Report for IP 187.2.78.51 already in database . . . moving on
# Report for IP 108.95.144.126 already in database . . . moving on
# Report for IP 173.50.18.134 already in database . . . moving on
# Report for IP 101.114.20.156 already in database . . . moving on
# Report for IP 70.171.108.66 already in database . . . moving on
# Report for IP 71.70.178.39 already in database . . . moving on
# Report for IP 69.125.161.209 already in database . . . moving on
# Report for IP 96.248.99.242 already in database . . . moving on
# Report for IP 186.101.70.43 already in database . . . moving on
# Report for IP 24.118.106.175 already in database . . . moving on
# Report for IP 200.125.163.26 already in database . . . moving on
# Report for IP 59.177.101.54 already in database . . . moving on
# Report for IP 71.125.61.238 already in database . . . moving on
# Report for IP 72.168.161.130 already in database . . . moving on
# Report for IP 187.188.158.103 already in database . . . moving on
# Report for IP 190.59.23.84 already in database . . . moving on
# Report for IP 119.236.248.83 already in database . . . moving on
# Report for IP 77.103.128.39 already in database . . . moving on
# Report for IP 41.45.220.63 already in database . . . moving on
# Report for IP 186.83.21.154 already in database . . . moving on
# Report for IP 49.144.200.144 already in database . . . moving on
# Report for IP 83.23.241.221 already in database . . . moving on
# Report for IP 12.21.46.2 already in database . . . moving on
# Report for IP 216.183.130.91 already in database . . . moving on
# Report for IP 58.160.120.186 already in database . . . moving on
# Report for IP 179.210.194.73 already in database . . . moving on
# Report for IP 135.23.137.40 already in database . . . moving on
# Report for IP 190.93.37.247 already in database . . . moving on
# Report for IP 108.20.143.188 already in database . . . moving on
# Report for IP 123.126.82.56 already in database . . . moving on
# Report for IP 108.197.64.107 already in database . . . moving on
# Report for IP 70.194.100.34 already in database . . . moving on
# Report for IP 182.48.111.228 already in database . . . moving on
# Report for IP 186.208.208.22 already in database . . . moving on
# Report for IP 103.7.16.73 already in database . . . moving on
# Report for IP 157.193.10.8 already in database . . . moving on
# Report for IP 117.204.133.121 already in database . . . moving on
# Report for IP 189.158.84.99 already in database . . . moving on
# Report for IP 151.29.152.76 already in database . . . moving on
# Report for IP 62.210.203.169 already in database . . . moving on
# Report for IP 72.22.156.10 already in database . . . moving on
# Report for IP 112.206.9.248 already in database . . . moving on
# Report for IP 76.99.202.78 already in database . . . moving on
# Report for IP 98.229.157.214 already in database . . . moving on
# Report for IP 75.92.110.200 already in database . . . moving on
# Report for IP 201.82.184.67 already in database . . . moving on
# Report for IP 81.193.25.202 already in database . . . moving on
# Report for IP 66.138.57.190 already in database . . . moving on
# Report for IP 173.239.196.65 already in database . . . moving on
# Report for IP 201.19.142.101 already in database . . . moving on
# Report for IP 125.238.34.76 already in database . . . moving on
# Report for IP 66.46.114.130 already in database . . . moving on
# Report for IP 67.130.75.232 already in database . . . moving on
# Report for IP 71.176.236.252 already in database . . . moving on
# Report for IP 209.89.235.57 already in database . . . moving on
# Report for IP 218.102.149.236 already in database . . . moving on
# Report for IP 216.211.117.58 already in database . . . moving on
# Report for IP 136.152.17.252 already in database . . . moving on
# Report for IP 86.45.238.96 already in database . . . moving on
# Report for IP 46.239.120.16 already in database . . . moving on
# Report for IP 62.152.13.187 already in database . . . moving on
# Report for IP 108.16.45.218 already in database . . . moving on
# Report for IP 31.3.236.245 already in database . . . moving on
# Report for IP 87.207.175.62 already in database . . . moving on
# Report for IP 174.88.147.20 already in database . . . moving on
# Report for IP 124.243.158.28 already in database . . . moving on
# Report for IP 81.33.168.57 already in database . . . moving on
# Report for IP 27.32.77.43 already in database . . . moving on
# Report for IP 50.254.48.62 already in database . . . moving on
# Report for IP 171.66.208.4 already in database . . . moving on
# Report for IP 81.100.53.217 already in database . . . moving on
# Report for IP 189.250.169.251 already in database . . . moving on
# Report for IP 188.78.165.242 already in database . . . moving on
# Report for IP 193.50.95.150 already in database . . . moving on
# Report for IP 167.88.18.143 already in database . . . moving on
# Report for IP 95.122.193.121 already in database . . . moving on
# Report for IP 190.203.175.239 already in database . . . moving on
# Report for IP 190.115.47.137 already in database . . . moving on
# Report for IP 132.156.109.29 already in database . . . moving on
# Report for IP 84.56.100.84 already in database . . . moving on
# Report for IP 82.222.59.188 already in database . . . moving on
# Report for IP 118.163.32.144 already in database . . . moving on
# Report for IP 82.95.156.188 already in database . . . moving on
# Report for IP 145.107.8.177 already in database . . . moving on
# Report for IP 70.67.87.73 already in database . . . moving on
# Report for IP 196.3.98.59 already in database . . . moving on
# Report for IP 58.7.234.244 already in database . . . moving on
# Report for IP 72.11.221.226 already in database . . . moving on
# Report for IP 109.255.234.59 already in database . . . moving on
# Report for IP 89.99.155.49 already in database . . . moving on
# Report for IP 5.28.76.173 already in database . . . moving on
# Report for IP 83.84.113.160 already in database . . . moving on
# Report for IP 189.142.97.190 already in database . . . moving on
# Report for IP 108.11.7.7 already in database . . . moving on
# Report for IP 190.229.63.194 already in database . . . moving on
# Report for IP 84.226.51.79 already in database . . . moving on
# Report for IP 84.229.83.225 already in database . . . moving on
# Report for IP 173.206.253.200 already in database . . . moving on
# Report for IP 107.107.61.49 already in database . . . moving on
# Report for IP 67.20.205.202 already in database . . . moving on
# Report for IP 68.2.195.46 already in database . . . moving on
# Report for IP 109.145.199.157 already in database . . . moving on
# Report for IP 37.11.54.131 already in database . . . moving on
# Report for IP 31.39.157.225 already in database . . . moving on
# Report for IP 68.227.255.237 already in database . . . moving on
# Report for IP 87.167.48.208 already in database . . . moving on
# Report for IP 2.216.165.123 already in database . . . moving on
# Report for IP 88.17.37.38 already in database . . . moving on
# Report for IP 62.14.247.234 already in database . . . moving on
# Report for IP 77.58.107.212 already in database . . . moving on
# Report for IP 62.18.251.21 already in database . . . moving on
# Report for IP 118.209.220.98 already in database . . . moving on
# Report for IP 75.140.103.15 already in database . . . moving on
# Report for IP 204.88.187.11 already in database . . . moving on
# Report for IP 84.83.91.162 already in database . . . moving on
# Report for IP 60.242.123.98 already in database . . . moving on
# Report for IP 162.242.26.27 already in database . . . moving on
# Report for IP 82.168.62.41 already in database . . . moving on
# Report for IP 80.114.137.6 already in database . . . moving on
# Report for IP 70.15.88.200 already in database . . . moving on
# Report for IP 67.247.11.11 already in database . . . moving on
# Report for IP 85.4.193.249 already in database . . . moving on
# Report for IP 59.167.79.89 already in database . . . moving on
# Report for IP 198.175.152.211 already in database . . . moving on
# Report for IP 2.40.143.228 already in database . . . moving on
# Report for IP 173.13.105.35 already in database . . . moving on
# Report for IP 83.235.183.187 already in database . . . moving on
# Report for IP 99.240.152.232 already in database . . . moving on
# Report for IP 86.155.105.138 already in database . . . moving on
# Report for IP 132.156.144.248 already in database . . . moving on
# Report for IP 201.66.179.68 already in database . . . moving on
# Report for IP 117.195.70.26 already in database . . . moving on
# Report for IP 187.172.37.61 already in database . . . moving on
# Report for IP 87.167.2.182 already in database . . . moving on
# Report for IP 131.94.186.11 already in database . . . moving on
# Report for IP 145.108.145.31 already in database . . . moving on
# Report for IP 98.127.196.216 already in database . . . moving on
# Report for IP 213.179.212.82 already in database . . . moving on
# Report for IP 158.111.236.102 already in database . . . moving on
# Report for IP 208.179.241.200 already in database . . . moving on
# Report for IP 71.233.37.189 already in database . . . moving on
# Report for IP 198.176.208.45 already in database . . . moving on
# Report for IP 94.214.186.200 already in database . . . moving on
# Report for IP 163.178.105.73 already in database . . . moving on
# Report for IP 41.37.249.9 already in database . . . moving on
# Report for IP 77.172.229.128 already in database . . . moving on
# Report for IP 77.171.127.138 already in database . . . moving on
# Report for IP 5.56.251.197 already in database . . . moving on
# Report for IP 187.191.7.91 already in database . . . moving on
# Report for IP 213.214.59.206 already in database . . . moving on
# Report for IP 77.250.80.69 already in database . . . moving on
# Report for IP 184.70.155.74 already in database . . . moving on
# Report for IP 87.223.217.14 already in database . . . moving on
# Report for IP 108.63.20.130 already in database . . . moving on
# Report for IP 206.248.222.200 already in database . . . moving on
# Report for IP 77.153.16.42 already in database . . . moving on
# Report for IP 41.204.236.222 already in database . . . moving on
# Report for IP 81.107.108.255 already in database . . . moving on
# Report for IP 204.187.67.17 already in database . . . moving on
# Report for IP 165.206.230.66 already in database . . . moving on
# Report for IP 178.252.157.184 already in database . . . moving on
# Report for IP 202.153.47.124 already in database . . . moving on
# Report for IP 115.97.245.188 already in database . . . moving on
# Report for IP 188.32.169.172 already in database . . . moving on
# Report for IP 89.101.76.100 already in database . . . moving on
# Report for IP 69.132.13.78 already in database . . . moving on
# Report for IP 71.240.119.125 already in database . . . moving on
# Report for IP 77.98.98.35 already in database . . . moving on
# Report for IP 217.117.125.68 already in database . . . moving on
# Report for IP 37.105.39.78 already in database . . . moving on
# Report for IP 24.0.136.183 already in database . . . moving on
# Report for IP 188.171.57.207 already in database . . . moving on
# Report for IP 89.69.200.134 already in database . . . moving on
# Report for IP 81.60.159.33 already in database . . . moving on
# Report for IP 95.28.74.247 already in database . . . moving on
# Report for IP 63.237.41.163 already in database . . . moving on
# Report for IP 41.37.246.190 already in database . . . moving on
# Report for IP 88.0.25.75 already in database . . . moving on
# Report for IP 82.95.110.253 already in database . . . moving on
# Report for IP 90.0.178.17 already in database . . . moving on
# Report for IP 115.240.59.127 already in database . . . moving on
# Report for IP 187.106.22.25 already in database . . . moving on
# Report for IP 47.63.38.170 already in database . . . moving on
# Report for IP 173.81.139.61 already in database . . . moving on
# Report for IP 190.211.204.162 already in database . . . moving on
# Report for IP 185.19.20.104 already in database . . . moving on
# Report for IP 89.119.149.126 already in database . . . moving on
# Report for IP 31.7.61.170 already in database . . . moving on
# Report for IP 176.219.147.39 already in database . . . moving on
# Report for IP 14.139.69.200 already in database . . . moving on
# Report for IP 218.106.182.57 already in database . . . moving on
# Report for IP 115.135.96.16 already in database . . . moving on
# Report for IP 88.9.94.85 already in database . . . moving on
# Report for IP 213.85.69.121 already in database . . . moving on
# Report for IP 81.204.59.217 already in database . . . moving on
# Report for IP 107.196.32.105 already in database . . . moving on
# Report for IP 132.251.226.183 already in database . . . moving on
# Report for IP 217.64.16.76 already in database . . . moving on
# Report for IP 195.241.106.23 already in database . . . moving on
# Report for IP 188.48.246.141 already in database . . . moving on
# Report for IP 164.85.17.102 already in database . . . moving on
# Report for IP 200.16.117.198 already in database . . . moving on
# Report for IP 83.84.87.68 already in database . . . moving on
# Report for IP 94.71.192.6 already in database . . . moving on
# Report for IP 190.45.186.202 already in database . . . moving on
# Report for IP 79.147.247.0 already in database . . . moving on
# Report for IP 71.95.125.211 already in database . . . moving on
# Report for IP 84.124.226.180 already in database . . . moving on
# Report for IP 94.216.110.151 already in database . . . moving on
# Report for IP 117.200.35.243 already in database . . . moving on
# Report for IP 186.23.224.165 already in database . . . moving on
# Report for IP 189.3.205.189 already in database . . . moving on
# Report for IP 200.5.106.14 already in database . . . moving on
# Report for IP 76.121.35.57 already in database . . . moving on
# Report for IP 193.43.186.4 already in database . . . moving on
# Report for IP 85.76.64.102 already in database . . . moving on
# Report for IP 141.135.61.37 already in database . . . moving on
# Report for IP 68.199.137.47 already in database . . . moving on
# Report for IP 60.241.183.91 already in database . . . moving on
# Report for IP 191.71.106.127 already in database . . . moving on
# Report for IP 150.129.140.10 already in database . . . moving on
# Report for IP 93.163.53.182 already in database . . . moving on
# Report for IP 83.160.50.222 already in database . . . moving on
# Report for IP 74.77.230.68 already in database . . . moving on
# Report for IP 31.210.96.219 already in database . . . moving on
# Report for IP 98.218.53.89 already in database . . . moving on
# Report for IP 109.34.22.107 already in database . . . moving on
# Report for IP 72.170.228.204 already in database . . . moving on
# Report for IP 180.160.242.94 already in database . . . moving on
# Report for IP 189.135.123.73 already in database . . . moving on
# Report for IP 104.37.2.35 already in database . . . moving on
# Report for IP 93.103.190.37 already in database . . . moving on
# Report for IP 37.210.51.92 already in database . . . moving on
# Report for IP 217.64.16.72 already in database . . . moving on
# Report for IP 50.78.239.161 already in database . . . moving on
# Report for IP 187.104.62.167 already in database . . . moving on
# Report for IP 76.74.153.36 already in database . . . moving on
# Report for IP 188.4.131.96 already in database . . . moving on
# Report for IP 190.30.96.134 already in database . . . moving on
# Report for IP 2.34.182.99 already in database . . . moving on
# Report for IP 217.64.16.66 already in database . . . moving on
# Report for IP 178.115.130.199 already in database . . . moving on
# Report for IP 94.210.182.103 already in database . . . moving on
# Report for IP 200.86.17.106 already in database . . . moving on
# Report for IP 189.2.90.198 already in database . . . moving on
# Report for IP 217.64.16.75 already in database . . . moving on
# Report for IP 164.85.22.107 already in database . . . moving on
# Report for IP 116.203.72.26 already in database . . . moving on
# Report for IP 94.163.210.61 already in database . . . moving on
# Report for IP 212.203.67.5 already in database . . . moving on
# Report for IP 217.111.207.130 already in database . . . moving on
# Report for IP 118.91.187.15 already in database . . . moving on
# Report for IP 124.40.244.240 already in database . . . moving on
# Report for IP 128.68.62.187 already in database . . . moving on
# Report for IP 193.126.23.51 already in database . . . moving on
# Report for IP 202.45.187.54 already in database . . . moving on
# Report for IP 109.182.45.130 already in database . . . moving on
# Report for IP 117.239.213.254 already in database . . . moving on
# Report for IP 217.64.16.68 already in database . . . moving on
# Report for IP 82.176.10.3 already in database . . . moving on
# Report for IP 190.117.227.235 already in database . . . moving on
# Report for IP 204.14.76.17 already in database . . . moving on
# Report for IP 2.84.182.198 already in database . . . moving on
# Report for IP 114.94.23.19 already in database . . . moving on
# Report for IP 79.146.108.21 already in database . . . moving on
# Report for IP 203.190.248.30 already in database . . . moving on
# Report for IP 202.153.47.42 already in database . . . moving on
# Report for IP 41.45.63.73 already in database . . . moving on
# Report for IP 87.221.22.79 already in database . . . moving on
# Report for IP 86.50.146.212 already in database . . . moving on
# Report for IP 186.204.170.70 already in database . . . moving on
# Report for IP 196.214.55.25 already in database . . . moving on
# Report for IP 111.68.103.3 already in database . . . moving on
# Report for IP 145.118.91.239 already in database . . . moving on
# Report for IP 178.250.215.74 already in database . . . moving on
# Report for IP 95.46.237.176 already in database . . . moving on
# Report for IP 78.147.182.91 already in database . . . moving on
# Report for IP 177.9.217.74 already in database . . . moving on
# Report for IP 188.25.39.120 already in database . . . moving on
# Report for IP 109.26.134.36 already in database . . . moving on
# Report for IP 50.134.22.116 already in database . . . moving on
# Report for IP 96.3.170.213 already in database . . . moving on
# Report for IP 2.81.151.110 already in database . . . moving on
# Report for IP 198.40.232.146 already in database . . . moving on
# Report for IP 217.64.16.71 already in database . . . moving on
# Report for IP 24.38.208.169 already in database . . . moving on
# Report for IP 61.230.159.106 already in database . . . moving on
# Report for IP 150.216.170.98 already in database . . . moving on
# Report for IP 41.13.182.123 already in database . . . moving on
# Report for IP 77.172.89.241 already in database . . . moving on
# Report for IP 76.218.101.123 already in database . . . moving on
# Report for IP 5.254.97.99 already in database . . . moving on
# Report for IP 59.92.205.55 already in database . . . moving on
# Report for IP 164.41.4.26 already in database . . . moving on
# Report for IP 62.252.153.60 already in database . . . moving on
# Report for IP 182.16.234.13 already in database . . . moving on
# Report for IP 190.43.233.230 already in database . . . moving on
# Report for IP 124.6.181.54 already in database . . . moving on
# Report for IP 190.179.187.131 already in database . . . moving on
# Report for IP 189.122.185.186 already in database . . . moving on
# Report for IP 91.75.70.162 already in database . . . moving on
# Report for IP 159.190.251.57 already in database . . . moving on
# Report for IP 148.241.224.2 already in database . . . moving on
# Report for IP 213.37.151.104 already in database . . . moving on
# Report for IP 60.247.107.194 already in database . . . moving on
# Report for IP 123.126.82.59 already in database . . . moving on
# Report for IP 70.28.64.86 already in database . . . moving on
# Report for IP 220.227.45.73 already in database . . . moving on
# Report for IP 164.85.81.102 already in database . . . moving on
# Report for IP 217.64.16.70 already in database . . . moving on
# Report for IP 196.205.25.222 already in database . . . moving on
# Report for IP 98.221.151.182 already in database . . . moving on
# Report for IP 2.87.178.80 already in database . . . moving on
# Report for IP 72.78.235.251 already in database . . . moving on
# Report for IP 178.192.0.58 already in database . . . moving on
# Report for IP 96.21.224.189 already in database . . . moving on
# Report for IP 81.154.168.73 already in database . . . moving on
# Report for IP 50.168.253.242 already in database . . . moving on
# Report for IP 80.222.112.174 already in database . . . moving on
# Report for IP 91.198.10.19 already in database . . . moving on
# Report for IP 116.49.212.151 already in database . . . moving on
# Report for IP 194.7.153.125 already in database . . . moving on
# Report for IP 68.40.188.50 already in database . . . moving on
# Report for IP 132.246.86.99 already in database . . . moving on
# Report for IP 90.2.82.144 already in database . . . moving on
# Report for IP 213.46.193.198 already in database . . . moving on
# Report for IP 24.171.228.200 already in database . . . moving on
# Report for IP 182.19.247.88 already in database . . . moving on
# Report for IP 89.210.196.79 already in database . . . moving on
# Report for IP 129.242.204.170 already in database . . . moving on
# Report for IP 145.107.161.108 already in database . . . moving on
# Report for IP 76.126.245.236 already in database . . . moving on
# Report for IP 142.163.54.162 already in database . . . moving on
# Report for IP 62.28.179.174 already in database . . . moving on
# Report for IP 39.51.48.39 already in database . . . moving on
# Report for IP 118.137.191.200 already in database . . . moving on
# Report for IP 81.193.248.86 already in database . . . moving on
# Report for IP 188.4.114.176 already in database . . . moving on
# Report for IP 152.88.90.185 already in database . . . moving on
# Report for IP 92.109.151.223 already in database . . . moving on
# Report for IP 119.74.22.119 already in database . . . moving on
# Report for IP 186.84.192.255 already in database . . . moving on
# Report for IP 207.10.131.81 already in database . . . moving on
# Report for IP 186.59.22.226 already in database . . . moving on
# Report for IP 82.222.106.161 already in database . . . moving on
# Report for IP 210.6.85.89 already in database . . . moving on
# Report for IP 145.107.180.153 already in database . . . moving on
# Report for IP 213.140.15.194 already in database . . . moving on
# Report for IP 145.118.79.32 already in database . . . moving on
# Report for IP 77.231.172.144 already in database . . . moving on
# Report for IP 50.242.48.211 already in database . . . moving on
# Report for IP 212.4.22.133 already in database . . . moving on
# Report for IP 62.232.109.146 already in database . . . moving on
# Report for IP 182.69.31.148 already in database . . . moving on
# Report for IP 77.173.213.178 already in database . . . moving on
# Report for IP 177.104.253.36 already in database . . . moving on
# Report for IP 141.227.1.38 already in database . . . moving on
# Report for IP 99.49.114.100 already in database . . . moving on
# Report for IP 144.122.239.185 already in database . . . moving on
# Report for IP 152.88.211.128 already in database . . . moving on
# Report for IP 201.217.133.235 already in database . . . moving on
# Report for IP 142.232.88.27 already in database . . . moving on
# Report for IP 92.45.169.247 already in database . . . moving on
# Report for IP 83.86.144.119 already in database . . . moving on
# Report for IP 90.193.198.22 already in database . . . moving on
# Report for IP 182.55.157.17 already in database . . . moving on
# Report for IP 212.250.190.200 already in database . . . moving on
# Report for IP 132.229.250.33 already in database . . . moving on
# Report for IP 85.242.147.241 already in database . . . moving on
# Report for IP 1.123.55.247 already in database . . . moving on
# Report for IP 132.229.201.155 already in database . . . moving on
# Report for IP 86.162.209.142 already in database . . . moving on
# Report for IP 91.18.62.243 already in database . . . moving on
# Report for IP 103.26.225.160 already in database . . . moving on
# Report for IP 196.21.83.196 already in database . . . moving on
# Report for IP 2.122.233.145 already in database . . . moving on
# Report for IP 77.250.65.201 already in database . . . moving on
# Report for IP 84.85.44.251 already in database . . . moving on
# Report for IP 145.118.233.75 already in database . . . moving on
# Report for IP 89.142.6.56 already in database . . . moving on
# Report for IP 123.150.68.118 already in database . . . moving on
# Report for IP 61.90.216.133 already in database . . . moving on
# Report for IP 96.57.215.250 already in database . . . moving on
# Report for IP 94.65.192.153 already in database . . . moving on
# Report for IP 118.103.234.143 already in database . . . moving on
# Report for IP 154.58.89.17 already in database . . . moving on
# Report for IP 62.221.58.140 already in database . . . moving on
# Report for IP 117.192.45.48 already in database . . . moving on
# Report for IP 83.165.29.51 already in database . . . moving on
# Report for IP 213.93.191.141 already in database . . . moving on
# Report for IP 41.45.187.103 already in database . . . moving on
# Report for IP 77.0.253.209 already in database . . . moving on
# Report for IP 46.14.218.40 already in database . . . moving on
# Report for IP 141.244.109.7 already in database . . . moving on
# Report for IP 191.176.243.122 already in database . . . moving on
# Report for IP 131.224.251.101 already in database . . . moving on
# Report for IP 137.224.252.10 already in database . . . moving on
# Report for IP 145.118.84.169 already in database . . . moving on
# Report for IP 82.236.198.35 already in database . . . moving on
# Report for IP 164.85.21.106 already in database . . . moving on
# Report for IP 94.191.186.75 already in database . . . moving on
# Report for IP 195.68.180.241 already in database . . . moving on
# Report for IP 50.46.227.159 already in database . . . moving on
# Report for IP 145.118.93.211 already in database . . . moving on
# Report for IP 115.64.132.7 already in database . . . moving on
# Report for IP 83.92.86.31 already in database . . . moving on
# Report for IP 94.165.66.66 already in database . . . moving on
# Report for IP 83.81.254.245 already in database . . . moving on
# Report for IP 118.200.19.253 already in database . . . moving on
# Report for IP 212.69.47.201 already in database . . . moving on
# Report for IP 120.127.18.116 already in database . . . moving on
# Report for IP 197.251.231.226 already in database . . . moving on
# Report for IP 168.187.190.226 already in database . . . moving on
# Report for IP 37.31.207.8 already in database . . . moving on
# Report for IP 86.160.137.70 already in database . . . moving on
# Report for IP 147.210.57.133 already in database . . . moving on
# Report for IP 31.61.129.171 already in database . . . moving on
# Report for IP 62.169.86.126 already in database . . . moving on
# Report for IP 89.96.238.226 already in database . . . moving on
# Report for IP 89.64.228.225 already in database . . . moving on
# Report for IP 1.1.178.77 already in database . . . moving on
# Report for IP 2.39.157.21 already in database . . . moving on
# Report for IP 150.237.204.184 already in database . . . moving on
# Report for IP 95.67.101.203 already in database . . . moving on
# Report for IP 192.107.56.137 already in database . . . moving on
# Report for IP 129.241.53.210 already in database . . . moving on
# Report for IP 200.110.218.162 already in database . . . moving on
# Report for IP 95.60.97.140 already in database . . . moving on
# Report for IP 91.90.234.185 already in database . . . moving on
# Report for IP 183.193.228.28 already in database . . . moving on
# Report for IP 92.45.142.228 already in database . . . moving on
# Report for IP 147.27.45.176 already in database . . . moving on
# Report for IP 109.188.126.151 already in database . . . moving on
# Report for IP 42.3.142.119 already in database . . . moving on
# Report for IP 79.129.39.178 already in database . . . moving on
# Report for IP 190.205.195.196 already in database . . . moving on
# Report for IP 103.15.63.34 already in database . . . moving on
# Report for IP 179.178.81.176 already in database . . . moving on
# Report for IP 149.172.4.120 already in database . . . moving on
# Report for IP 131.220.199.12 already in database . . . moving on
# Report for IP 209.122.203.10 already in database . . . moving on
# Report for IP 211.26.200.206 already in database . . . moving on
# Report for IP 193.52.24.72 already in database . . . moving on
# Report for IP 14.139.45.242 already in database . . . moving on
# Report for IP 122.177.222.124 already in database . . . moving on
# Report for IP 180.183.85.46 already in database . . . moving on
# Report for IP 139.216.152.211 already in database . . . moving on
# Report for IP 132.229.140.157 already in database . . . moving on
# Report for IP 59.183.145.201 already in database . . . moving on
# Report for IP 88.182.56.85 already in database . . . moving on
# Report for IP 145.118.84.93 already in database . . . moving on
# Report for IP 59.148.215.1 already in database . . . moving on
# Report for IP 112.198.77.89 already in database . . . moving on
# Report for IP 77.165.169.3 already in database . . . moving on
# Report for IP 191.11.15.120 already in database . . . moving on
# Report for IP 62.226.12.122 already in database . . . moving on
# Report for IP 62.169.208.221 already in database . . . moving on
# Report for IP 91.238.76.17 already in database . . . moving on
# Report for IP 39.249.156.148 already in database . . . moving on
# Report for IP 196.200.49.122 already in database . . . moving on
# Report for IP 69.159.74.150 already in database . . . moving on
# Report for IP 94.116.162.117 already in database . . . moving on
# Report for IP 145.107.160.98 already in database . . . moving on
# Report for IP 182.55.115.163 already in database . . . moving on
# Report for IP 141.63.163.202 already in database . . . moving on
# Report for IP 195.240.45.250 already in database . . . moving on
# Report for IP 82.84.179.246 already in database . . . moving on
# Report for IP 147.27.45.157 already in database . . . moving on
# Report for IP 82.144.216.2 already in database . . . moving on
# Report for IP 5.81.108.150 already in database . . . moving on
# Report for IP 82.139.80.213 already in database . . . moving on
# Report for IP 61.91.146.84 already in database . . . moving on
# Report for IP 82.157.225.81 already in database . . . moving on
# Report for IP 213.88.151.140 already in database . . . moving on
# Report for IP 145.118.88.221 already in database . . . moving on
# Report for IP 41.189.161.39 already in database . . . moving on
# Report for IP 128.65.248.159 already in database . . . moving on
# Report for IP 194.7.217.254 already in database . . . moving on
# Report for IP 95.172.68.149 already in database . . . moving on
# Report for IP 78.101.209.243 already in database . . . moving on
# Report for IP 59.92.133.47 already in database . . . moving on
# Report for IP 124.6.142.138 already in database . . . moving on
# Report for IP 178.252.161.100 already in database . . . moving on
# Report for IP 50.131.23.193 already in database . . . moving on
# Report for IP 94.71.157.247 already in database . . . moving on
# Report for IP 78.56.112.67 already in database . . . moving on
# Report for IP 115.70.240.23 already in database . . . moving on
# Report for IP 87.205.20.139 already in database . . . moving on
# Report for IP 81.17.164.162 already in database . . . moving on
# Report for IP 59.189.52.33 already in database . . . moving on
# Report for IP 124.148.44.142 already in database . . . moving on
# Report for IP 212.68.255.92 already in database . . . moving on
# Report for IP 217.64.16.69 already in database . . . moving on
# Report for IP 87.15.235.141 already in database . . . moving on
# Report for IP 50.13.183.60 already in database . . . moving on
# Report for IP 202.159.140.146 already in database . . . moving on
# Report for IP 178.42.58.119 already in database . . . moving on
# Report for IP 217.126.94.187 already in database . . . moving on
# Report for IP 41.150.188.1 already in database . . . moving on
# Report for IP 90.208.3.95 already in database . . . moving on
# Report for IP 109.152.80.96 already in database . . . moving on
# Report for IP 203.8.131.32 already in database . . . moving on
# Report for IP 42.61.153.47 already in database . . . moving on
# Report for IP 84.84.187.35 already in database . . . moving on
# Report for IP 91.5.245.137 already in database . . . moving on
# Report for IP 83.240.239.148 already in database . . . moving on
# Report for IP 128.131.136.192 already in database . . . moving on
# Report for IP 79.75.205.125 already in database . . . moving on
# Report for IP 99.95.162.122 already in database . . . moving on
# Report for IP 69.163.36.90 already in database . . . moving on
# Report for IP 116.203.73.141 already in database . . . moving on
# Report for IP 174.92.171.171 already in database . . . moving on
# Report for IP 195.169.134.56 already in database . . . moving on
# Report for IP 122.53.114.130 already in database . . . moving on
# Report for IP 81.214.221.244 already in database . . . moving on
# Report for IP 87.81.250.155 already in database . . . moving on
# Report for IP 62.169.208.219 already in database . . . moving on
# Report for IP 95.45.86.151 already in database . . . moving on
# Report for IP 145.118.87.231 already in database . . . moving on
# Report for IP 130.223.251.169 already in database . . . moving on
# Report for IP 42.70.200.29 already in database . . . moving on
# Report for IP 41.37.230.79 already in database . . . moving on
# Report for IP 110.33.231.117 already in database . . . moving on
# Report for IP 221.238.82.195 already in database . . . moving on
# Report for IP 41.135.83.53 already in database . . . moving on
# Report for IP 46.40.60.36 already in database . . . moving on
# Report for IP 115.186.108.103 already in database . . . moving on
# Report for IP 177.198.16.125 already in database . . . moving on
# Report for IP 122.176.167.119 already in database . . . moving on
# Report for IP 183.89.174.253 already in database . . . moving on
# Report for IP 189.219.77.43 already in database . . . moving on
# Report for IP 76.102.25.244 already in database . . . moving on
# Report for IP 121.123.141.242 already in database . . . moving on
# Report for IP 181.64.52.242 already in database . . . moving on
# Report for IP 211.25.130.177 already in database . . . moving on
# Report for IP 207.203.45.67 already in database . . . moving on
# Report for IP 219.76.188.121 already in database . . . moving on
# Report for IP 130.102.82.61 already in database . . . moving on
# Report for IP 123.150.255.195 already in database . . . moving on
# Report for IP 80.29.123.196 already in database . . . moving on
# Report for IP 87.236.6.14 already in database . . . moving on
# Report for IP 14.139.161.3 already in database . . . moving on
# Report for IP 58.68.97.34 already in database . . . moving on
# Report for IP 203.116.251.232 already in database . . . moving on
# Report for IP 124.169.65.62 already in database . . . moving on
# Report for IP 122.161.153.175 already in database . . . moving on
# Report for IP 213.113.241.199 already in database . . . moving on
# Report for IP 91.141.0.163 already in database . . . moving on
# Report for IP 49.96.45.46 already in database . . . moving on
# Report for IP 87.220.118.100 already in database . . . moving on
# Report for IP 197.17.182.8 already in database . . . moving on
# Report for IP 112.198.28.54 already in database . . . moving on
# Report for IP 145.62.32.131 already in database . . . moving on
# Report for IP 68.101.174.90 already in database . . . moving on
# Report for IP 201.184.90.0 already in database . . . moving on
# Report for IP 110.159.143.214 already in database . . . moving on
# Report for IP 173.177.233.182 already in database . . . moving on
# Report for IP 182.180.189.111 already in database . . . moving on
# Report for IP 65.49.68.185 already in database . . . moving on
# Report for IP 98.118.168.32 already in database . . . moving on
# Report for IP 73.170.199.2 already in database . . . moving on
# Report for IP 120.150.104.248 already in database . . . moving on
# Report for IP 68.0.38.188 already in database . . . moving on
# Report for IP 103.8.194.85 already in database . . . moving on
# Report for IP 72.214.59.56 already in database . . . moving on
# Report for IP 216.99.216.142 already in database . . . moving on
# Report for IP 69.11.2.251 already in database . . . moving on
# Report for IP 130.130.37.85 already in database . . . moving on
# Report for IP 192.74.250.36 already in database . . . moving on
# Report for IP 136.186.19.143 already in database . . . moving on
# Report for IP 82.245.86.151 already in database . . . moving on
# Report for IP 24.113.145.4 already in database . . . moving on
# Report for IP 23.114.216.116 already in database . . . moving on
# Report for IP 175.136.219.147 already in database . . . moving on
# Report for IP 70.231.227.98 already in database . . . moving on
# Report for IP 107.204.184.238 already in database . . . moving on
# Report for IP 190.129.40.61 already in database . . . moving on
# Report for IP 89.210.21.2 already in database . . . moving on
# Report for IP 37.216.3.230 already in database . . . moving on
# Report for IP 181.114.127.173 already in database . . . moving on
# Report for IP 86.120.227.17 already in database . . . moving on
# Report for IP 189.170.123.55 already in database . . . moving on
# Report for IP 174.119.238.73 already in database . . . moving on
# Report for IP 112.198.82.3 already in database . . . moving on
# Report for IP 121.222.76.105 already in database . . . moving on
# Report for IP 122.53.69.5 already in database . . . moving on
# Report for IP 122.161.203.22 already in database . . . moving on
# Report for IP 71.38.116.217 already in database . . . moving on
# Report for IP 65.129.195.200 already in database . . . moving on
# Report for IP 85.140.85.17 already in database . . . moving on
# Report for IP 190.42.6.67 already in database . . . moving on
# Report for IP 203.130.234.140 already in database . . . moving on
# Report for IP 125.212.122.146 already in database . . . moving on
# Report for IP 217.64.16.67 already in database . . . moving on
# Report for IP 108.87.142.202 already in database . . . moving on
# Report for IP 94.182.192.143 already in database . . . moving on
# Report for IP 76.120.70.79 already in database . . . moving on
# Report for IP 152.83.196.122 already in database . . . moving on
# Report for IP 98.194.134.155 already in database . . . moving on
# Report for IP 201.243.190.227 already in database . . . moving on
# Report for IP 186.85.219.153 already in database . . . moving on
# Report for IP 24.84.165.75 already in database . . . moving on
# ...
# Report for IP 186.44.131.179 already in database . . . moving on
# Report for IP 95.45.87.39 already in database . . . moving on
# Report for IP 190.99.119.6 already in database . . . moving on
# Report for IP 94.71.190.110 already in database . . . moving on
# Report for IP 112.65.50.137 already in database . . . moving on
# Report for IP 36.224.192.39 already in database . . . moving on
# Report for IP 81.195.20.32 already in database . . . moving on
# Report for IP 217.110.101.138 already in database . . . moving on
# Report for IP 46.200.67.247 already in database . . . moving on
# Report for IP 94.192.34.69 already in database . . . moving on
# Report for IP 105.236.241.140 already in database . . . moving on
# Report for IP 84.114.249.214 already in database . . . moving on
# Report for IP 172.5.172.31 already in database . . . moving on
# Report for IP 101.172.255.239 already in database . . . moving on
# Report for IP 145.94.252.70 already in database . . . moving on
# Report for IP 109.232.41.54 already in database . . . moving on
# Report for IP 157.86.169.40 already in database . . . moving on
# Report for IP 79.251.113.147 already in database . . . moving on
# Report for IP 120.164.26.43 already in database . . . moving on
# Report for IP 36.77.182.236 already in database . . . moving on
# Report for IP 77.28.175.111 already in database . . . moving on
# Report for IP 108.183.35.27 already in database . . . moving on
# Report for IP 178.3.188.213 already in database . . . moving on
# Report for IP 145.118.89.133 already in database . . . moving on
# Report for IP 92.146.80.248 already in database . . . moving on
# Report for IP 196.34.16.50 already in database . . . moving on
# Report for IP 84.147.93.65 already in database . . . moving on
# Report for IP 200.50.125.250 already in database . . . moving on
# Report for IP 84.121.129.234 already in database . . . moving on
# Report for IP 203.59.29.81 already in database . . . moving on
# Report for IP 151.44.146.72 already in database . . . moving on
# Report for IP 172.56.0.193 already in database . . . moving on
# Report for IP 182.64.4.177 already in database . . . moving on
# Report for IP 124.82.43.228 already in database . . . moving on
# Report for IP 108.9.16.103 already in database . . . moving on
# Report for IP 58.11.144.176 already in database . . . moving on
# Report for IP 166.181.82.190 already in database . . . moving on
# Report for IP 202.45.187.57 already in database . . . moving on
# Report for IP 116.203.75.81 already in database . . . moving on
# Report for IP 195.114.238.6 already in database . . . moving on
# Report for IP 213.160.143.34 already in database . . . moving on
# Report for IP 115.66.82.41 already in database . . . moving on
# Report for IP 49.52.46.70 already in database . . . moving on
# Report for IP 196.46.244.16 already in database . . . moving on
# Report for IP 86.177.177.224 already in database . . . moving on
# Report for IP 203.110.246.230 already in database . . . moving on
# Report for IP 77.243.22.2 already in database . . . moving on
# Report for IP 78.147.177.75 already in database . . . moving on
# Report for IP 89.78.232.76 already in database . . . moving on
# Report for IP 92.45.189.8 already in database . . . moving on
# Report for IP 59.167.130.133 already in database . . . moving on
# Report for IP 59.149.8.221 already in database . . . moving on
# Report for IP 105.112.8.20 already in database . . . moving on
# Report for IP 98.166.139.83 already in database . . . moving on
# Report for IP 194.24.2.5 already in database . . . moving on
# Report for IP 88.72.252.60 already in database . . . moving on
# Report for IP 39.48.172.58 already in database . . . moving on
# Report for IP 157.181.182.146 already in database . . . moving on
# Report for IP 46.70.214.197 already in database . . . moving on
# Report for IP 206.186.131.130 already in database . . . moving on
# Report for IP 75.155.179.50 already in database . . . moving on
# Report for IP 119.17.46.178 already in database . . . moving on
# Report for IP 101.103.53.145 already in database . . . moving on
# Report for IP 85.74.91.121 already in database . . . moving on
# Report for IP 94.71.152.76 already in database . . . moving on
# Report for IP 70.70.255.196 already in database . . . moving on
# Report for IP 84.137.105.39 already in database . . . moving on
# Report for IP 116.50.78.41 already in database . . . moving on
# Report for IP 89.101.65.159 already in database . . . moving on
# Report for IP 222.181.160.136 already in database . . . moving on
# Report for IP 192.131.129.167 already in database . . . moving on
# Report for IP 84.83.169.20 already in database . . . moving on
# Report for IP 200.131.3.109 already in database . . . moving on
# Report for IP 192.189.128.15 already in database . . . moving on
# Report for IP 14.139.185.114 already in database . . . moving on
# Report for IP 189.169.48.130 already in database . . . moving on
# Report for IP 131.130.246.204 already in database . . . moving on
# Report for IP 60.180.157.132 already in database . . . moving on
# Report for IP 58.106.10.119 already in database . . . moving on
# Report for IP 82.171.79.108 already in database . . . moving on
# Report for IP 207.157.91.128 already in database . . . moving on
# Report for IP 190.222.250.120 already in database . . . moving on
# Report for IP 81.149.64.242 already in database . . . moving on
# Report for IP 122.161.19.104 already in database . . . moving on
# Report for IP 212.250.168.85 already in database . . . moving on
# Report for IP 62.245.148.129 already in database . . . moving on
# Report for IP 31.61.140.252 already in database . . . moving on
# Report for IP 132.231.213.70 already in database . . . moving on
# Report for IP 77.95.242.33 already in database . . . moving on
# Report for IP 146.50.145.122 already in database . . . moving on
# Report for IP 173.183.124.248 already in database . . . moving on
# Report for IP 41.97.37.38 already in database . . . moving on
# Report for IP 134.2.251.6 already in database . . . moving on
# Report for IP 110.32.69.247 already in database . . . moving on
# Report for IP 193.136.74.116 already in database . . . moving on
# Report for IP 64.134.169.44 already in database . . . moving on
# Report for IP 80.103.192.30 already in database . . . moving on
# Report for IP 5.151.2.142 already in database . . . moving on
# Report for IP 87.223.170.184 already in database . . . moving on
# Report for IP 183.192.235.218 already in database . . . moving on
# Report for IP 212.90.178.66 already in database . . . moving on
# Report for IP 217.87.127.49 already in database . . . moving on
# Report for IP 197.255.166.247 already in database . . . moving on
# Report for IP 91.135.13.220 already in database . . . moving on
# Report for IP 59.95.160.222 already in database . . . moving on
# Report for IP 193.190.189.12 already in database . . . moving on
# Report for IP 62.194.183.217 already in database . . . moving on
# Report for IP 5.201.12.30 already in database . . . moving on
# Report for IP 194.78.203.70 already in database . . . moving on
# Report for IP 166.171.58.72 already in database . . . moving on
# Report for IP 41.57.6.77 already in database . . . moving on
# Report for IP 93.108.198.168 already in database . . . moving on
# Report for IP 178.8.25.134 already in database . . . moving on
# Report for IP 196.46.244.17 already in database . . . moving on
# Report for IP 119.82.94.123 already in database . . . moving on
# Report for IP 182.64.220.208 already in database . . . moving on
# Report for IP 59.88.57.89 already in database . . . moving on
# Report for IP 87.221.1.181 already in database . . . moving on
# Report for IP 145.118.224.81 already in database . . . moving on
# Report for IP 213.87.141.155 already in database . . . moving on
# Report for IP 178.157.49.242 already in database . . . moving on
# Report for IP 154.68.222.100 already in database . . . moving on
# Report for IP 220.239.47.93 already in database . . . moving on
# Report for IP 115.241.177.179 already in database . . . moving on
# Report for IP 141.23.68.108 already in database . . . moving on
# Report for IP 80.248.10.131 already in database . . . moving on
# Report for IP 164.85.19.104 already in database . . . moving on
# Report for IP 89.93.53.33 already in database . . . moving on
# Report for IP 70.231.225.255 already in database . . . moving on
# Report for IP 212.35.106.161 already in database . . . moving on
# Report for IP 145.118.95.59 already in database . . . moving on
# Report for IP 27.99.124.169 already in database . . . moving on
# Report for IP 154.69.131.248 already in database . . . moving on
# Report for IP 79.234.134.200 already in database . . . moving on
# Report for IP 116.212.201.132 already in database . . . moving on
# Report for IP 199.254.105.106 already in database . . . moving on
# Report for IP 141.227.1.33 already in database . . . moving on
# Report for IP 109.99.128.52 already in database . . . moving on
# Report for IP 114.108.237.179 already in database . . . moving on
# Report for IP 83.178.68.187 already in database . . . moving on
# Report for IP 87.221.28.143 already in database . . . moving on
# Report for IP 90.21.155.65 already in database . . . moving on
# Report for IP 88.235.174.223 already in database . . . moving on
# Report for IP 182.18.219.135 already in database . . . moving on
# Report for IP 31.192.152.187 already in database . . . moving on
# Report for IP 95.91.171.180 already in database . . . moving on
# Report for IP 203.215.121.215 already in database . . . moving on
# Report for IP 89.180.129.142 already in database . . . moving on
# Report for IP 145.118.88.27 already in database . . . moving on
# Report for IP 117.200.43.125 already in database . . . moving on
# Report for IP 70.74.181.37 already in database . . . moving on
# Report for IP 206.190.157.215 already in database . . . moving on
# Report for IP 80.2.93.28 already in database . . . moving on
# Report for IP 114.108.238.113 already in database . . . moving on
# Report for IP 109.186.123.5 already in database . . . moving on
# Report for IP 189.217.77.209 already in database . . . moving on
# Report for IP 200.150.81.125 already in database . . . moving on
# Report for IP 193.227.123.211 already in database . . . moving on
# Report for IP 46.246.37.224 already in database . . . moving on
# Report for IP 134.178.23.23 already in database . . . moving on
# Report for IP 121.217.228.2 already in database . . . moving on
# Report for IP 194.54.182.169 already in database . . . moving on
# Report for IP 89.143.130.157 already in database . . . moving on
# Report for IP 165.228.184.123 already in database . . . moving on
# Report for IP 2.223.205.237 already in database . . . moving on
# Report for IP 124.184.178.76 already in database . . . moving on
# Report for IP 190.204.208.169 already in database . . . moving on
# Report for IP 189.63.73.84 already in database . . . moving on
# Report for IP 1.39.0.247 already in database . . . moving on
# Report for IP 109.193.211.197 already in database . . . moving on
# Report for IP 199.119.233.168 already in database . . . moving on
# Report for IP 187.198.142.179 already in database . . . moving on
# Report for IP 49.195.134.45 already in database . . . moving on
# Report for IP 109.225.93.155 already in database . . . moving on
# Report for IP 183.28.21.144 already in database . . . moving on
# Report for IP 109.188.124.158 already in database . . . moving on
# Report for IP 201.229.164.72 already in database . . . moving on
# Report for IP 80.30.242.13 already in database . . . moving on
# Report for IP 184.148.0.161 already in database . . . moving on
# Report for IP 121.203.37.104 already in database . . . moving on
# Report for IP 94.71.138.120 already in database . . . moving on
# Report for IP 97.92.123.26 already in database . . . moving on
# Report for IP 41.71.139.23 already in database . . . moving on
# Report for IP 82.169.169.36 already in database . . . moving on
# Report for IP 95.138.94.78 already in database . . . moving on
# Report for IP 2.50.190.168 already in database . . . moving on
# Report for IP 98.16.84.93 already in database . . . moving on
# Report for IP 124.127.76.126 already in database . . . moving on
# Report for IP 115.186.108.188 already in database . . . moving on
# Report for IP 124.243.152.53 already in database . . . moving on
# Report for IP 123.126.82.124 already in database . . . moving on
# Report for IP 121.97.80.66 already in database . . . moving on
# Report for IP 147.27.70.209 already in database . . . moving on
# Report for IP 77.180.189.245 already in database . . . moving on
# Report for IP 94.212.227.206 already in database . . . moving on
# Report for IP 58.7.155.220 already in database . . . moving on
# Report for IP 190.234.106.227 already in database . . . moving on
# Report for IP 220.231.35.218 already in database . . . moving on
# Report for IP 181.247.0.199 already in database . . . moving on
# Report for IP 98.27.53.120 already in database . . . moving on
# Report for IP 75.190.151.216 already in database . . . moving on
# Report for IP 58.6.134.84 already in database . . . moving on
# Report for IP 194.230.159.223 already in database . . . moving on
# Report for IP 210.8.191.100 already in database . . . moving on
# Report for IP 69.173.127.101 already in database . . . moving on
# Report for IP 174.116.97.10 already in database . . . moving on
# Report for IP 50.107.27.229 already in database . . . moving on
# Report for IP 179.7.124.165 already in database . . . moving on
# Report for IP 69.38.132.3 already in database . . . moving on
# Report for IP 1.1.179.151 already in database . . . moving on
# Report for IP 116.50.78.195 already in database . . . moving on
# Report for IP 2.84.187.43 already in database . . . moving on
# Report for IP 117.200.32.81 already in database . . . moving on
# Report for IP 69.66.243.31 already in database . . . moving on
# Report for IP 202.21.159.249 already in database . . . moving on
# Report for IP 115.242.108.121 already in database . . . moving on
# Report for IP 50.243.179.1 already in database . . . moving on
# Report for IP 174.116.175.67 already in database . . . moving on
# Report for IP 178.26.238.207 already in database . . . moving on
# Report for IP 71.232.157.35 already in database . . . moving on
# Report for IP 81.250.168.77 already in database . . . moving on
# Report for IP 70.27.141.35 already in database . . . moving on
# Report for IP 158.182.114.212 already in database . . . moving on
# Report for IP 201.255.30.29 already in database . . . moving on
# Report for IP 105.155.67.14 already in database . . . moving on
# Report for IP 190.148.227.145 already in database . . . moving on
# Report for IP 93.87.60.180 already in database . . . moving on
# Report for IP 177.33.94.232 already in database . . . moving on
# Report for IP 210.66.161.42 already in database . . . moving on
# Report for IP 150.93.243.127 already in database . . . moving on
# Report for IP 46.24.95.43 already in database . . . moving on
# Report for IP 76.21.247.139 already in database . . . moving on
# Report for IP 131.112.181.203 already in database . . . moving on
# Report for IP 64.223.172.47 already in database . . . moving on
# Report for IP 89.180.132.254 already in database . . . moving on
# Report for IP 149.171.146.100 already in database . . . moving on
# Report for IP 165.228.250.189 already in database . . . moving on
# Report for IP 176.86.199.202 already in database . . . moving on
# Report for IP 117.120.16.138 already in database . . . moving on
# Report for IP 180.173.209.176 already in database . . . moving on
# Report for IP 83.92.53.18 already in database . . . moving on
# There was an error . . . moving on
# Report for IP 194.7.217.254 already in database . . . moving on
# There was an error . . . moving on
# Report for IP 202.176.202.136 already in database . . . moving on
# There was an error . . . moving on
# There was an error . . . moving on
# There was an error . . . moving on
# There was an error . . . moving on
# There was an error . . . moving on
# Report for IP 95.172.74.49 already in database . . . moving on
# Report for IP 62.190.139.132 already in database . . . moving on
